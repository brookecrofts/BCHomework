# %%
import pandas as pd

# %%
df=pd.DataFrame()

#class DataFrame(): 
#    def __init__(self):

class Student():
    def __init__(self):
        self.name='Kevin'
        self.grade='A'
    
student_A=Student()
student_B=Student()
print(student_A.name)
print(student_B.name)
# Out:
# Kevin
# Kevin

# %%
purchase_csv = "./Resources/purchase_data.csv"
purchase_df = pd.read_csv(purchase_csv)

# %%
purchase_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#total number of players
#purchase_df.dtypes
player_number = len(purchase_df["SN"].unique())
player_number
# Out:
# 576

# %%
# purchase_df.loc[rows, columns]
# purchase_df.loc[[row1, row2], [column1, column2]]
# purchase_df.loc[:, 'SN']
# Out:
# array(['Lisim78', 'Lisovynya38', 'Ithergue48', 'Chamassasya86',
#        'Iskosia90', 'Yalae81', 'Itheria73', 'Iskjaskst81', 'Undjask33',
#        'Chanosian48', 'Inguron55', 'Haisrisuir60', 'Saelaephos52',
#        'Assjaskan73', 'Saesrideu94', 'Lisassa64', 'Lisirra25',
#        'Zontibe81', 'Reunasu60', 'Chamalo71', 'Iathenudil29',
#        'Phiarithdeu40', 'Siarithria38', 'Eyrian71', 'Siala43',
#        'Lisirra87', 'Lirtossa84', 'Eusri44', 'Aela59', 'Tyida79',
#        'Idai61', 'Farusrian86', 'Aeralria27', 'Haillyrgue51', 'Sondim73',
#        'Jeyciman68', 'Idaisuir85', 'Seuthep89', 'Reulae52',
#        'Sondilsaya62', 'Aerithriaphos45', 'Assosia88', 'Aidaillodeu39',
#        'Aelly27', 'Tyeosri53', 'Haerith37', 'Yasrisu92', 'Chanuchi25',
#        'Asur96', 'Iaralrgue74', 'Chanosia34', 'Aelin32', 'Ilosianya35',
#        'Zhisrisu83', 'Phaelap26', 'Raesty92', 'Palyon91', 'Tyisur83',
#        'Yaliru88', 'Yadanu52', 'Jiskimya77', 'Yadaphos40', 'Alo38',
# ...

# %%
# data={
#   'Total': player_number
#   }
# player_summary=pd.DataFrame(data, index=[0])
data={
    'Total': [player_number]
    }
player_summary=pd.DataFrame(data)
# player_summary=pd.DataFrame({"Total Players": [player_number]})
player_summary
# Out:
#    Total
# 0    576

# %%
item_count = len(purchase_df["Item ID"].unique()) 
num_purchases = purchase_df["Item ID"].count()
# total_revenue = purchase_df["Price"].sum()
total_revenue = sum(purchase_df["Price"])
average_price = ('${:.2f}'.format(total_revenue/num_purchases))
summary_df= pd.DataFrame({"Number of Unique Items": [item_count],
                        "Average Price": [average_price],
                        "Number of Purchases": [num_purchases],
                        "Total Revenue": [total_revenue]})
summary_df
# Out:
#    Number of Unique Items Average Price  Number of Purchases  Total Revenue
# 0                     179         $3.05                  780        2379.77

# %%
purchase_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
grouped_df=purchase_df.loc[:, ['Gender', 'Price']].groupby('Gender')
# this is a Series with 'Gender' as index
gender_avg_price=grouped_df['Price'].mean()
gender_count=grouped_df['Gender'].count()
summary=pd.DataFrame(gender_avg_price, columns=['Average Price'])
summary['Total Count']=gender_count
summary
# Out:
#                       Average Price  Total Count
# Gender
# Female                          NaN          113
# Male                            NaN          652
# Other / Non-Disclosed           NaN           15

# %%
df_gb = purchase_df.groupby(['Gender'])
df_gb = df_gb['SN'].unique()
df_group_male = pd.DataFrame(data={'Male':df_gb['Male']})
malecount = len(df_group_male)
df_group_female = pd.DataFrame(data={'Female':df_gb['Female']})
femalecount = len(df_group_female)
df_group_other = pd.DataFrame(data={'Other / Non-Disclosed':df_gb['Other / Non-Disclosed']})
othercount = len(df_group_other)
percentmale=round((malecount/(malecount+femalecount+othercount)*100),2)
percentfemale=round((femalecount/(malecount+femalecount+othercount)*100),2)
percentother=round((othercount/(malecount+femalecount+othercount)*100),2)
gender_data = ({'Gender': ['Male','Female','Other/Non-Disclosed'],
                        'Total Count':[malecount, femalecount, othercount],
                        'Percentage of Players': [percentmale, percentfemale, percentother]})
gn_output = pd.DataFrame(gender_data)
gn_output['Percentage of Players'] = gn_output['Percentage of Players'].map('{:.2f}%'.format)
gn_output
# Out:
#                 Gender  Total Count Percentage of Players
# 0                 Male          484                84.03%
# 1               Female           81                14.06%
# 2  Other/Non-Disclosed           11                 1.91%

# %%
#CODE for Purchasing Analysis by Gender
#purchase_df.groupby('Gender',sort = True)['Item ID'].count()
by_gender = purchase_df.groupby('Gender')
malecount = len(by_gender.groups["Male"])
femalecount = len(by_gender.groups["Female"])
othercount = len(by_gender.groups["Other / Non-Disclosed"])
gender_purchase = purchase_df.groupby('Gender').sum()['Price']
female_pp = round((gender_purchase['Female']),2) 
male_pp = round((gender_purchase['Male']),2)
other_pp = round((gender_purchase['Other / Non-Disclosed']),2)
total_purchase_pp = purchase_df.groupby('Gender').mean()['Price']
avg_fempp = round((total_purchase_pp['Female']),2)
avg_malpp = round((total_purchase_pp['Male']),2)
avg_othpp = round((total_purchase_pp['Other / Non-Disclosed']),2)
gender_data = ({'Gender': ['Male','Female','Other/Non-Disclosed'],
                       'Purchase Count': [malecount, femalecount, othercount],
                        'Average Purchase Price': [avg_malpp, avg_fempp, avg_othpp],
                        'Total Purchase Value': [male_pp, female_pp, other_pp],
                        'Avg Total Puchase per Person':[malecount, malecount, malecount]})
gender_data = pd.DataFrame(gender_data)
gender_data

#gender_data['Total Purchase Value']= list(purchase_df.groupby('Gender').sum()['Price'])
#gender_data['Average Purchase Price'] = list(purchase_df.groupby('Gender').sum()[])
#gender_data['Average Purchase Price'] = purchase_df.groupby(['Gender']).agg({'Price': "mean"})


# with a DataFrame, you can perform math between two columns
# 'Total Purchase Value' / 'Purchase Count'
# Out:
#                 Gender  Purchase Count  Average Purchase Price  \
# 0                 Male             652                    3.02
# 1               Female             113                    3.20
# 2  Other/Non-Disclosed              15                    3.35
#
#    Total Purchase Value  Avg Total Puchase per Person
# 0               1967.64                           652
# 1                361.94                           652
# 2                 50.19                           652

# %%
#CODE REFERENCES
total_purchase_pp = purchase_df.groupby('Gender').mean()['Price']
avg_fempp = total_purchase_pp['Female']
avg_fempp
#gender_purchase = purchase_df.groupby('Gender').sum()['Price']
#female_pp = round((gender_purchase['Female']),2) 
#female_pp
#total_value_male = pd.DataFrame(data={'Male':by_gender.groups['Male']}).count()
#total_value_male
#total_purchase_pp = purchase_df.groupby(['Gender']).agg({'Price': "mean"})
#total_purchase_pp
# Out:
# 3.203008849557519

# %%
# purchase_df.groupby(['Age']).count()["Price"]

# %%
subset_df=purchase_df.loc[:, ['SN', 'Age']]
subset_df['Age_bin']=pd.cut(subset_df['Age'], bins=5)
print(len(subset_df))
subset_df=subset_df.drop_duplicates('SN')
print(len(subset_df))
subset_df=subset_df.drop('Age', axis=1)
# subset_df.groupby('Age_bin').count()/780
# Out:
# 780
# 576
#                      SN
# Age_bin
# (6.962, 14.6]  0.050000
# (14.6, 22.2]   0.343590
# (22.2, 29.8]   0.223077
# (29.8, 37.4]   0.092308
# (37.4, 45.0]   0.029487

# %%
#Age Demographics

bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]

# Create the names for the five bins
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

age_groups = pd.cut(purchase_df["Age"], bins, labels=group_names)



#finds count of each age group
age_totals = age_groups.value_counts()

#only count UNIQUE!!

# df = purchase_df.groupby(['SN']).count()["Price"]
# age_totals = purchase_df.drop_duplicates()
#age_totals = purchase_df.drop_duplicates(subset=None, keep='first', inplace=False)

player_number = len(purchase_df['SN'].unique())
age_pct = (age_totals / player_number) * 100

#Create DF
age_pop = pd.DataFrame({"Total Count": age_totals, "Percentage of Players": age_pct})
age_pop = age_pop.sort_index()
age_pop['Percentage of Players'] = age_pop['Percentage of Players'].map('{:.2f}%'.format)
age_pop
# Out:
#        Total Count Percentage of Players
# <10             23                 3.99%
# 10-14           28                 4.86%
# 15-19          136                23.61%
# 20-24          365                63.37%
# 25-29          101                17.53%
# 30-34           73                12.67%
# 35-39           41                 7.12%
# 40+             13                 2.26%

# %%
#Puchasing Analysis

bins = [0, 9, 14, 19, 24, 29, 34, 39, 75]

group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

age_groups = pd.cut(purchase_df["Age"], bins, labels=group_names)

df = purchase_df.groupby(['Price'])
# age_purchase_value = df.mean()['Price']

#finds count of each age group
all_count = age_groups.value_counts()

#find avg purchase price
# top_spend_avg = df.mean()['Price']

#find total purchase value
# top_spend = df.sum()["Price"]


#Create DF
age_pop = pd.DataFrame({"Total Count": all_count, 
#                         "Average Purchase Price": all_count,
#                        "Total Purchase Value": all_purchase, 
#                         "Avg Total Purchase per Person": age_count
                       })
age_pop = age_pop.sort_index()
age_pop
# Out:
#        Total Count
# <10             23
# 10-14           28
# 15-19          136
# 20-24          365
# 25-29          101
# 30-34           73
# 35-39           41
# 40+             13

# %%
#Top Spenders
df = purchase_df.groupby(['SN'])
top_spend_group = purchase_df['Price']
top_spend = purchase_df['SN'].value_counts()

# CALCULATE AVG PURCHASE PRICE AND COUNT
top_spend_average = df.mean()['Price']
top_spend_count = df.count()['Price']

#Calculate Total Purchase Value
top_spend = df.sum()["Price"]

top_spend_group = pd.DataFrame({"Purchase Count": top_spend_count, "Average Purchase Price": top_spend_average,
                       "Total Purchase Value": top_spend})

top_spend_group = top_spend_group.sort_values("Total Purchase Value", ascending=False)
top_spend_group.head(5)

# age_pop = age_pop.sort_index()
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10

# %%
#MOST POPULAR ITEMS

#Extract 3 columns I need
popular_items = purchase_df[['Item ID', 'Item Name', 'Price']]

purchase_df['Item ID'].value_counts()

popular_group = popular_items.groupby(['Item ID', 'Item Name']).count()
item_count = purchase_df['Item Name'].value_counts()
item_id = purchase_df['Item ID'].value_counts
# popular_group = popular_group['Item ID'].unique()
# purchase_df('Item_ID').unique()
popular_group = pd.DataFrame({'Item ID': item_id, 
                             'Item Name': item_count,
                             'Purchase Count': popular_group,
                             'Item Price': item_id,
                             'Total Purchase Value': item_id})
popular_group.head()
# Out:
#                                                                                         Item ID  \
# Final Critic                                  <bound method IndexOpsMixin.value_counts of 0 ...
# Oathbreaker, Last Hope of the Breaking Storm  <bound method IndexOpsMixin.value_counts of 0 ...
# Persuasion                                    <bound method IndexOpsMixin.value_counts of 0 ...
# Nirvana                                       <bound method IndexOpsMixin.value_counts of 0 ...
# Fiery Glass Crusader                          <bound method IndexOpsMixin.value_counts of 0 ...
#
#                                               Item Name   Purchase Count  \
# Final Critic                                         13  (P, r, i, c, e)
# Oathbreaker, Last Hope of the Breaking Storm         12  (P, r, i, c, e)
# Persuasion                                            9  (P, r, i, c, e)
# Nirvana                                               9  (P, r, i, c, e)
# ...

# %%
# Most popular item code

# %%
purchase_df['Item ID'].value_counts()
# Out:
# 92     13
# 178    12
# 108     9
# 132     9
# 82      9
#        ..
# 104     1
# 27      1
# 134     1
# 118     1
# 91      1
# Name: Item ID, Length: 179, dtype: int64

# %%
purchase_df['Item Name'].value_counts()
# Out:
# Final Critic                                    13
# Oathbreaker, Last Hope of the Breaking Storm    12
# Persuasion                                       9
# Nirvana                                          9
# Fiery Glass Crusader                             9
#                                                 ..
# Endbringer                                       1
# Betrayer                                         1
# Gladiator's Glaive                               1
# The Decapitator                                  1
# Ghost Reaver, Longsword of Magic                 1
# Name: Item Name, Length: 179, dtype: int64

# %%
purchase_df['Price']
# Out:
# 0      3.53
# 1      1.56
# 2      4.88
# 3      3.27
# 4      1.44
#        ...
# 775    3.54
# 776    1.63
# 777    3.46
# 778    4.19
# 779    4.60
# Name: Price, Length: 780, dtype: float64

# %%
#Most Profitable Items
